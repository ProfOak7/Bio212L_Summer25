# %%
import pandas as pd
import statistics
from statistics import mean, stdev
from scipy.stats import sem
import scipy.stats as stats
import matplotlib.pyplot as plt
#include if using a jupyter notebook, remove if using a .py file
# %matplotlib inline

# %%
#Optional - Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
#Import the excel file
df = pd.read_excel (r'./Lab2_Population.xlsx', index_col = 0)
df
# Out:
#                    G1  G2  G3  G4
# Forks               1   0   0   0
# Spoons              1   1   1   0
# knives              1   1   1   1
# Tongue Depressors   1   1   0   0
# Forceps             1   2   3   4

# %%
df = df.transpose()
df
# Out:
#     Forks  Spoons  knives  Tongue Depressors  Forceps
# G1      1       1       1                  1        1
# G2      0       1       1                  1        2
# G3      0       1       1                  0        3
# G4      0       0       1                  0        4

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'Forks', marker = 'o')
df.plot.line(ax = ax, y = 'Spoons', marker = 'o')
df.plot.line(ax = ax, y = 'knives', marker = 'o')
df.plot.line(ax = ax, y = 'Forceps', marker = 'o')
df.plot.line(ax = ax, y = 'Tongue Depressors', marker = 'o')

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_xlabel("Generation Number")
ax.set_ylabel("Population Size")
ax.set_title("Population Size Over Time")
# Out:
# Text(0.5, 1.0, 'Population Size Over Time')

# %%
#Import the excel file
df = pd.read_excel (r'./Lab2_Offspring.xlsx', index_col = 0)
df
# Out:
#                     G1   G2   G3   G4
# Type
# Forks               43    0    0    0
# Spoons              55   98  148    0
# knives             120  211  170  148
# Tongue Depressors   66   96    0    0
# Forceps            125  246  312  463

# %%
df = df.transpose()
df
# Out:
# Type  Forks  Spoons  knives  Tongue Depressors  Forceps
# G1       43      55     120                 66      125
# G2        0      98     211                 96      246
# G3        0     148     170                  0      312
# G4        0       0     148                  0      463

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'Forks', marker = 'o')
df.plot.line(ax = ax, y = 'Spoons', marker = 'o')
df.plot.line(ax = ax, y = 'knives', marker = 'o')
df.plot.line(ax = ax, y = 'Forceps', marker = 'o')
df.plot.line(ax = ax, y = 'Tongue Depressors', marker = 'o')

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_xlabel("Generation Number")
ax.set_ylabel("Number of Offspring")
ax.set_title("Number of Offspring Over Time")
# Out:
# Text(0.5, 1.0, 'Number of Offspring Over Time')
